# %% [markdown]
# **01-Linear Regression with Python**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/content/drive/MyDrive/BSc. in CSE Journey/4_Year/3rd Year/L3T2/Data Mining and Machine Learning Lab CSE326/Lab-04/USA_Housing.csv')
