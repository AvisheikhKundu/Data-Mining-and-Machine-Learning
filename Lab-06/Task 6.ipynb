# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np

# Original data
data = {
    'weather': ['Sunny', 'Sunny', 'Overcast', 'Rainy', 'Rainy', 'Rainy', 'Overcast', 'Sunny', 'Sunny', 'Rainy', 'Sunny', 'Overcast', 'Overcast', 'Rainy'],
    'temp': ['Hot', 'Hot', 'Hot', 'Mild', 'Cool', 'Cool', 'Cool', 'Mild', 'Cool', 'Mild', 'Mild', 'Mild', 'Hot', 'Mild'],
    'play': ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
}

# Create DataFrame
df = pd.DataFrame(data)

# Add new columns
np.random.seed(1)  # For reproducibility
df['humidity'] = np.random.choice(['High', 'Normal', 'Low'], size=len(df))
df['windy'] = np.random.choice([True, False], size=len(df))
df['time_of_day'] = np.random.choice(['Morning', 'Afternoon', 'Evening'], size=len(df))
df['day_of_week'] = np.random.choice(['Weekday', 'Weekend'], size=len(df))

# Repeat the DataFrame to create enough data for sampling
df_expanded = pd.concat([df] * (1000 // len(df) + 1), ignore_index=True)

# Take 500 random samples
random_samples = df_expanded.sample(n=1000, random_state=1)

# Display the random samples
print(random_samples)
# Out:
#       weather  temp play humidity  windy time_of_day day_of_week
# 913     Rainy  Mild  Yes   Normal   True     Morning     Weekend
# 922  Overcast   Hot  Yes   Normal   True     Morning     Weekday
# 293     Rainy  Mild   No      Low  False     Morning     Weekend
# 555     Rainy  Mild  Yes   Normal  False     Evening     Weekday
# 582     Sunny  Cool  Yes     High   True   Afternoon     Weekday
# ..        ...   ...  ...      ...    ...         ...         ...
# 972  Overcast  Cool  Yes     High   True   Afternoon     Weekday
# 129     Rainy  Mild  Yes   Normal   True     Morning     Weekend
# 144     Rainy  Cool  Yes   Normal   True     Evening     Weekend
# 960     Sunny  Cool  Yes     High   True   Afternoon     Weekday
# 847     Sunny  Mild   No   Normal   True   Afternoon     Weekend
#
# [1000 rows x 7 columns]

# %%
df.head()
# Out:
#     weather  temp play humidity  windy time_of_day day_of_week
# 0     Sunny   Hot   No   Normal   True   Afternoon     Weekend
# 1     Sunny   Hot   No     High   True   Afternoon     Weekday
# 2  Overcast   Hot  Yes     High  False     Evening     Weekday
# 3     Rainy  Mild  Yes   Normal   True     Morning     Weekend
# 4     Rainy  Cool  Yes   Normal   True     Evening     Weekend

# %%
df.shape
# Out:
# (14, 7)

# %%
df.isnull().sum().sort_values(ascending=False).head()
# Out:
# weather     0
# temp        0
# play        0
# humidity    0
# windy       0
# dtype: int64

# %%
# Add new columns
np.random.seed(1)  # For reproducibility
df['humidity'] = np.random.choice(['High', 'Normal', 'Low'], size=len(df))
df['windy'] = np.random.choice([True, False], size=len(df))
df['time_of_day'] = np.random.choice(['Morning', 'Afternoon', 'Evening'], size=len(df))
df['day_of_week'] = np.random.choice(['Weekday', 'Weekend'], size=len(df))

# %%
random_samples['play'] = random_samples['play'].map({'Yes': 1, 'No': 0})

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# Assuming 'df' is your DataFrame and 'play' is your target column
# ... (Your previous code to create and preprocess 'df') ...

# Before splitting, remove rows with NaN in the target variable
df = df.dropna(subset=['play'])  # Assuming 'play' is your target column

# Now proceed with your train

# %%
from sklearn.linear_model import LogisticRegression
